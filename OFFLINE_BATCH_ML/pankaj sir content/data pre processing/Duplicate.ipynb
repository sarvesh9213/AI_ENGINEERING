# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.getcwd()
# Out:
# 'C:\\Users\\PANKAJ SHARMA'

# %%
#dataset = pd.read_csv(r"D:\desktop\ML\DATA\titanic_train.csv")
dataset = pd.read_csv(r"D:\desktop\ML\Machine Learning\MY ML NOTES\Preprocessing\titanic_dataset.csv")
dataset.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
dataset_dupicate = dataset.duplicated().sum()
dataset_dupicate
# Out:
# np.int64(24)

# %%
dataset = dataset.drop_duplicates(keep='first',inplace = True)

# %% [markdown]
# ![image.png](attachment:545f45a3-e7d3-4ef5-b7f4-df67ca9afc7e.png)

# %%
type(dataset)
# Out:
# numpy.int64

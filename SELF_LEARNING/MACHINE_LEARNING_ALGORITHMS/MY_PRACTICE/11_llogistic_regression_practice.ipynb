# %% [markdown]
# 1. Load Data
#       ↓
# 2. Clean Missing Values
#       ↓
# 3. Convert Categories to Numbers
#       ↓
# 4. Separate X and y
#       ↓
# 5. Train-Test Split
#       ↓
# 6. Create LogisticRegression()
#       ↓
# 7. model.fit()
#       ↓
# 8. model.predict()
#       ↓
# 9. Evaluate
